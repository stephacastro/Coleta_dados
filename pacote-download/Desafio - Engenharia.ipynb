# %% [markdown]
# # Desafio Engenharia de dados

# %%
import pandas as pd

# %%
# 1. Quantas linhas tem o arquivo CSV ?
df = pd.read_csv('C:\\Series_Temporais\\UDEMY_TSA_FINAL\\aluguel_certo.csv')
df.head()
# Out:
#             Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0       Copacabana        1      0       0    40  1700.0       500.0
# 1  Jardim Botânico        2      0       1   100  7000.0         NaN
# 2  Barra da Tijuca        0      4       0   150  5200.0      4020.0
# 3           Centro        1      0       0    15   800.0       390.0
# 4     Higienópolis        1      0       0    48   800.0       230.0
#
#                       Tipo    IPTU
# 0                Quitinete    60.0
# 1                     Casa     NaN
# 2  Conjunto Comercial/Sala  1111.0
# 3              Apartamento    20.0
# 4              Apartamento     NaN

# %%
# Resposta 32960 linhas × 9 colunas
df.shape
# Out:
# (32960, 9)

# %%
# 2. Renomeie a coluna 'Condominio' para 'Valor do Condomínio'
df.rename(columns={'Condominio': 'Valor do Condomínio'}, inplace=True)

# %%
df.head()
# Out:
#             Bairro  Quartos  Vagas  Suites  Area   Valor  Valor do Condomínio  \
# 0       Copacabana        1      0       0    40  1700.0                500.0
# 1  Jardim Botânico        2      0       1   100  7000.0                  NaN
# 2  Barra da Tijuca        0      4       0   150  5200.0               4020.0
# 3           Centro        1      0       0    15   800.0                390.0
# 4     Higienópolis        1      0       0    48   800.0                230.0
#
#                       Tipo    IPTU
# 0                Quitinete    60.0
# 1                     Casa     NaN
# 2  Conjunto Comercial/Sala  1111.0
# 3              Apartamento    20.0
# 4              Apartamento     NaN

# %%
# 3. Mostre cada valor de forma única da coluna 'Tipo'
df['Tipo'].unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
# 4. Limpe os valores nulos da coluna 'Valor'
# Contando todos os valores nulos presentes na coluna Valor
df.isnull().sum()
# Out:
# Bairro                     0
# Quartos                    0
# Vagas                      0
# Suites                     0
# Area                       0
# Valor                     17
# Valor do Condomínio     4093
# Tipo                       0
# IPTU                   10237
# dtype: int64

# %%
# eliminando todos os valores nulos da coluna valor e salvando a alteração no meu dataset
df.dropna(inplace=True)

# %%
# Contando novamente os valores nulos da coluna para me certificar que a alteração deu certo
df['Valor'].isnull().sum()
# Out:
# 0

# %%
# 5. Faça um filtro para apenas 2 quantos ou mais
filtro = df[df['Quartos'] >= 2]

# %%
filtro
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 6                     Cachambi        2      0       0    50   1300.0
# 11                      Grajaú        2      1       0    70   1500.0
# 12         Lins de Vasconcelos        3      1       1    90   1500.0
# 15                  Copacabana        4      3       1   243  13000.0
# 19     Freguesia (Jacarepaguá)        3      0       0    54    950.0
# ...                        ...      ...    ...     ...   ...      ...
# 32949                  Ipanema        3      1       2   150  15000.0
# 32952          Barra da Tijuca        5      3       4   450  15000.0
# 32953                    Méier        2      0       0    70    900.0
# 32956              Jacarepaguá        3      1       2    78   1800.0
# 32957     São Francisco Xavier        2      1       0    48   1400.0
#
#        Valor do Condomínio                Tipo    IPTU
# 6                    301.0         Apartamento    17.0
# ...

# %%
# 6. Busque por apenas 'Quitinete, Casa, Apartamento, Casa de Condominio, Casa de Vila'
df.loc[df['Tipo'].isin(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condominio', 'Casa de Vila'])]
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0                Copacabana        1      0       0    40  1700.0
# 1           Jardim Botânico        2      0       1   100  7000.0
# 3                    Centro        1      0       0    15   800.0
# 4              Higienópolis        1      0       0    48   800.0
# 5              Vista Alegre        3      1       0    70  1200.0
# ...                     ...      ...    ...     ...   ...     ...
# 32953                 Méier        2      0       0    70   900.0
# 32955                Centro        0      0       0    27   800.0
# 32956           Jacarepaguá        3      1       2    78  1800.0
# 32957  São Francisco Xavier        2      1       0    48  1400.0
# 32958                Leblon        2      0       0    70  3000.0
#
#        Valor do Condomínio         Tipo  IPTU
# 0                    500.0    Quitinete  60.0
# 1                      NaN         Casa   NaN
# ...

# %%
filtro_tipo
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0                Copacabana        1      0       0    40  1700.0
# 3                    Centro        1      0       0    15   800.0
# 6                  Cachambi        2      0       0    50  1300.0
# 11                   Grajaú        2      1       0    70  1500.0
# 12      Lins de Vasconcelos        3      1       1    90  1500.0
# ...                     ...      ...    ...     ...   ...     ...
# 32950                Tijuca        1      0       0    28  1000.0
# 32953                 Méier        2      0       0    70   900.0
# 32955                Centro        0      0       0    27   800.0
# 32956           Jacarepaguá        3      1       2    78  1800.0
# 32957  São Francisco Xavier        2      1       0    48  1400.0
#
#        Valor do Condomínio         Tipo  IPTU
# 0                    500.0    Quitinete  60.0
# 3                    390.0  Apartamento  20.0
# ...

# %%
# 7. Faça um filtro para 2 quartos ou mais com 40m²
# armazeando em uma variavel o meu filtro
selecao = (df.Quartos > 2) | (df.Area > 40)
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 32955    False
# 32956     True
# 32957     True
# 32958     True
# 32959     True
# Length: 32960, dtype: bool

# %%
# atribuindo o meu filtro a um dataframe
df2 = df[selecao]

# %%
df2.head()
# Out:
#                  Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 2       Barra da Tijuca        0      4       0   150   5200.0
# 6              Cachambi        2      0       0    50   1300.0
# 9                Centro        0      3       0   695  35000.0
# 11               Grajaú        2      1       0    70   1500.0
# 12  Lins de Vasconcelos        3      1       1    90   1500.0
#
#     Valor do Condomínio                     Tipo    IPTU
# 2                4020.0  Conjunto Comercial/Sala  1111.0
# 6                 301.0              Apartamento    17.0
# 9               19193.0  Conjunto Comercial/Sala  3030.0
# 11                642.0              Apartamento    74.0
# 12                455.0              Apartamento    14.0

# %%
# 8. Remova os valores acima de R$50.000 da coluna valor
filtro_valor = df[df['Valor'] > 50000].index

# %%
df.drop(filtro_valor, inplace=True)

# %%
df
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0                Copacabana        1      0       0    40   1700.0
# 2           Barra da Tijuca        0      4       0   150   5200.0
# 3                    Centro        1      0       0    15    800.0
# 6                  Cachambi        2      0       0    50   1300.0
# 9                    Centro        0      3       0   695  35000.0
# ...                     ...      ...    ...     ...   ...      ...
# 32953                 Méier        2      0       0    70    900.0
# 32955                Centro        0      0       0    27    800.0
# 32956           Jacarepaguá        3      1       2    78   1800.0
# 32957  São Francisco Xavier        2      1       0    48   1400.0
# 32959                Centro        0      0       0   250   6500.0
#
#        Valor do Condomínio                     Tipo    IPTU
# 0                    500.0                Quitinete    60.0
# ...

# %%
# 9. Crie uma nova coluna chamada “Valor Bruto” onde contém a soma de “Valor” + “Valor do Condomínio” 
# + “IPTU”
# atribui a soma das colunas a uma variavel
valor_bruto = df['Valor'] + df['Valor do Condomínio'] + df['IPTU']

# %%
# criei a nova coluna com a soma das colunas
df['Valor Bruto'] = valor_bruto

# %%
df.head()
# Out:
#             Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0       Copacabana        1      0       0    40   1700.0
# 2  Barra da Tijuca        0      4       0   150   5200.0
# 3           Centro        1      0       0    15    800.0
# 6         Cachambi        2      0       0    50   1300.0
# 9           Centro        0      3       0   695  35000.0
#
#    Valor do Condomínio                     Tipo    IPTU  Valor Bruto
# 0                500.0                Quitinete    60.0       2260.0
# 2               4020.0  Conjunto Comercial/Sala  1111.0      10331.0
# 3                390.0              Apartamento    20.0       1210.0
# 6                301.0              Apartamento    17.0       1618.0
# 9              19193.0  Conjunto Comercial/Sala  3030.0      57223.0

# %%
# 10. Crie uma nova coluna chamada “Valor por m²”, pegando o “Valor Bruto” e dividindo pelo valor da área 
# e arredonde os valores para duas casas após a vírgula
valor_metro = round((df['Valor Bruto'] / df['Area']), 2)

# %%
df['Valor por m²'] = valor_metro

# %%
df.head()
# Out:
#             Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0       Copacabana        1      0       0    40   1700.0
# 2  Barra da Tijuca        0      4       0   150   5200.0
# 3           Centro        1      0       0    15    800.0
# 6         Cachambi        2      0       0    50   1300.0
# 9           Centro        0      3       0   695  35000.0
#
#    Valor do Condomínio                     Tipo    IPTU  Valor Bruto  \
# 0                500.0                Quitinete    60.0       2260.0
# 2               4020.0  Conjunto Comercial/Sala  1111.0      10331.0
# 3                390.0              Apartamento    20.0       1210.0
# 6                301.0              Apartamento    17.0       1618.0
# 9              19193.0  Conjunto Comercial/Sala  3030.0      57223.0
#
#    Valor por m²
# 0         56.50
# 2         68.87
# 3         80.67
# 6         32.36
# 9         82.34

# %%
# 11. Limpe todos os valores nulos da coluna “Valor Bruto”
df['Valor Bruto'].isnull().sum()
# Out:
# 0

# %%
df.dropna(inplace=True)

# %%
df['Valor Bruto'].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#             Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0       Copacabana        1      0       0    40   1700.0
# 2  Barra da Tijuca        0      4       0   150   5200.0
# 3           Centro        1      0       0    15    800.0
# 6         Cachambi        2      0       0    50   1300.0
# 9           Centro        0      3       0   695  35000.0
#
#    Valor do Condomínio                     Tipo    IPTU  Valor Bruto  \
# 0                500.0                Quitinete    60.0       2260.0
# 2               4020.0  Conjunto Comercial/Sala  1111.0      10331.0
# 3                390.0              Apartamento    20.0       1210.0
# 6                301.0              Apartamento    17.0       1618.0
# 9              19193.0  Conjunto Comercial/Sala  3030.0      57223.0
#
#    Valor por m²
# 0         56.50
# 2         68.87
# 3         80.67
# 6         32.36
# 9         82.34

# %%
# 12. Gere um arquivo CSV dos dados
df.to_csv('aluguel_certo2.csv', index=False)
